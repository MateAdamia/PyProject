# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/survey_results_public.csv')
schema_data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/survey_results_schema.csv')
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# 4  Hobby;Contribute to open-source projects;Profe...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Colleague;Friend or family member;Other online...
# 4  Books / Physical media;Online Courses or Certi...
#
#                                      LearnCodeOnline  ...        Frequency_1  \
# 0                                                NaN  ...                NaN
# 1  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 2  Formal documentation provided by the owner of ...  ...  6-10 times a week
# 3  Formal documentation provided by the owner of ...  ...   1-2 times a week
# 4  Formal documentation provided by the owner of ...  ...   1-2 times a week
#
#          Frequency_2       Frequency_3         TimeSearching  \
# 0                NaN               NaN                   NaN
# 1   10+ times a week             Never   15-30 minutes a day
# 2  6-10 times a week  3-5 times a week   30-60 minutes a day
# 3   10+ times a week  1-2 times a week   15-30 minutes a day
# 4   1-2 times a week  3-5 times a week  60-120 minutes a day
#
#          TimeAnswering                                   ProfessionalTech  \
# 0                  NaN                                                NaN
# 1  15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 2  30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 3  30-60 minutes a day  Automated testing;Continuous integration (CI) ...
# 4  30-60 minutes a day  Microservices;Automated testing;Observability ...
#
#                                             Industry           SurveyLength  \
# 0                                                NaN                    NaN
# 1  Information Services, IT, Software Development...  Appropriate in length
# 2  Information Services, IT, Software Development...  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                              Other  Appropriate in length
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                        Easy         285,000.000
# 2                        Easy         250,000.000
# 3                        Easy         156,000.000
# 4  Neither easy nor difficult          23,456.000
#
# [5 rows x 84 columns]

# %%
df.shape

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
#  11  YearsCode                            87435 non-null  object
#  12  YearsCodePro                         66136 non-null  object
#  13  DevType                              76872 non-null  object
#  14  OrgSize                              65043 non-null  object
#  15  PurchaseInfluence                    64964 non-null  object
#  16  TechList                             60851 non-null  object
#  17  BuyNewTool                           83009 non-null  object
#  18  Country                              87973 non-null  object
#  19  Currency                             65334 non-null  object
#  20  CompTotal                            48225 non-null  float64
#  21  LanguageHaveWorkedWith               87140 non-null  object
#  22  LanguageWantToWorkWith               80709 non-null  object
#  23  DatabaseHaveWorkedWith               73435 non-null  object
#  24  DatabaseWantToWorkWith               60911 non-null  object
#  25  PlatformHaveWorkedWith               63628 non-null  object
#  26  PlatformWantToWorkWith               51308 non-null  object
#  27  WebframeHaveWorkedWith               66938 non-null  object
#  28  WebframeWantToWorkWith               56741 non-null  object
#  29  MiscTechHaveWorkedWith               57019 non-null  object
#  30  MiscTechWantToWorkWith               46848 non-null  object
#  31  ToolsTechHaveWorkedWith              77884 non-null  object
#  32  ToolsTechWantToWorkWith              68315 non-null  object
#  33  NEWCollabToolsHaveWorkedWith         85864 non-null  object
#  34  NEWCollabToolsWantToWorkWith         76649 non-null  object
#  35  OpSysPersonal use                    86557 non-null  object
#  36  OpSysProfessional use                78587 non-null  object
#  37  OfficeStackAsyncHaveWorkedWith       69090 non-null  object
#  38  OfficeStackAsyncWantToWorkWith       53743 non-null  object
#  39  OfficeStackSyncHaveWorkedWith        83439 non-null  object
#  40  OfficeStackSyncWantToWorkWith        69776 non-null  object
#  41  AISearchHaveWorkedWith               56328 non-null  object
#  42  AISearchWantToWorkWith               46150 non-null  object
#  43  AIDevHaveWorkedWith                  25904 non-null  object
#  44  AIDevWantToWorkWith                  19587 non-null  object
#  45  NEWSOSites                           87973 non-null  object
#  46  SOVisitFreq                          87140 non-null  object
#  47  SOAccount                            87852 non-null  object
#  48  SOPartFreq                           66061 non-null  object
#  49  SOComm                               87692 non-null  object
#  50  SOAI                                 47912 non-null  object
#  51  AISelect                             87973 non-null  object
#  52  AISent                               61501 non-null  object
#  53  AIAcc                                38594 non-null  object
#  54  AIBen                                61396 non-null  object
#  55  AIToolInterested in Using            32783 non-null  object
#  56  AIToolCurrently Using                36137 non-null  object
#  57  AIToolNot interested in Using        21069 non-null  object
#  58  AINextVery different                 12661 non-null  object
#  59  AINextNeither different nor similar  6599 non-null   object
#  60  AINextSomewhat similar               6238 non-null   object
#  61  AINextVery similar                   2621 non-null   object
#  62  AINextSomewhat different             23303 non-null  object
#  63  TBranch                              65768 non-null  object
#  64  ICorPM                               43668 non-null  object
#  65  WorkExp                              43579 non-null  float64
#  66  Knowledge_1                          42535 non-null  object
#  67  Knowledge_2                          41670 non-null  object
#  68  Knowledge_3                          41798 non-null  object
#  69  Knowledge_4                          41684 non-null  object
#  70  Knowledge_5                          41527 non-null  object
#  71  Knowledge_6                          41520 non-null  object
#  72  Knowledge_7                          41467 non-null  object
#  73  Knowledge_8                          41404 non-null  object
#  74  Frequency_1                          41916 non-null  object
#  75  Frequency_2                          41925 non-null  object
#  76  Frequency_3                          41054 non-null  object
#  77  TimeSearching                        42778 non-null  object
#  78  TimeAnswering                        42629 non-null  object
#  79  ProfessionalTech                     41783 non-null  object
#  80  Industry                             36774 non-null  object
#  81  SurveyLength                         86485 non-null  object
#  82  SurveyEase                           86554 non-null  object
#  83  ConvertedCompYearly                  48019 non-null  float64
# dtypes: float64(3), int64(1), object(80)
# memory usage: 57.2+ MB

# %%
schema_data["selector"].value_counts()#
# Out:
# MAVR       23
# SAVR       21
# Likert     16
# TB          9
# DL          4
# SL          3
# Browser     1
# HSLIDER     1
# Name: selector, dtype: int64

# %% [markdown]
# First, we reveal the difference between the column names in schema and survey
# datas.

# %%
first_array = np.array(df.columns)
second_array = np.array(schema_data["qname"])
first_array[~(np.isin(first_array, second_array))]
# Out:
# array(['ResponseId', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysPersonal use', 'OpSysProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'AISearchHaveWorkedWith', 'AISearchWantToWorkWith',
#        'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
#        'AIToolInterested in Using', 'AIToolCurrently Using',
#        'AIToolNot interested in Using', 'AINextVery different',
#        'AINextNeither different nor similar', 'AINextSomewhat similar',
#        'AINextVery similar', 'AINextSomewhat different',
#        'ConvertedCompYearly'], dtype=object)

# %% [markdown]
# Each question is devided by section:
# Section 1 / Basic Information Questions   ## Gramatikulad gasasworebeli iqneba

# %%
section1_df = schema_data.iloc[schema_data[schema_data["qname"] == "S1"].index[0]: schema_data[schema_data["qname"] == "S2"].index[0]]
section1_df
# Out:
#       qid             qname  \
# 4    QID1                S1
# 5    QID2        MainBranch
# 6  QID127               Age
# 7  QID296        Employment
# 8  QID308        RemoteWork
# 9  QID297  CodingActivities
#
#                                             question force_resp type selector
# 4  <span style="font-size:22px; font-family: aria...      False   DB       TB
# 5  Which of the following options best describes ...       True   MC     SAVR
# 6                                What is your age? *       True   MC     MAVR
# 7  Which of the following best describes your cur...      False   MC     MAVR
# 8  Which best describes your current work situation?      False   MC     SAVR
# 9  Which of the following best describes the code...      False   MC     MAVR

# %% [markdown]
# Section 2 / Education, Work and Career

# %%
section2_df = schema_data.iloc[schema_data[schema_data["qname"] == "S2"].index[0]: schema_data[schema_data["qname"] == "S3"].index[0]]
section2_df
# Out:
#        qid                 qname  \
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
#
#                                              question force_resp type selector
# 10  <span style="font-size:22px; font-family: aria...      False   DB       TB
# 11  Which of the following best describes the high...       True   MC     SAVR
# 12   How do you learn to code? Select all that apply.      False   MC     MAVR
# 13  What online resources do you use to learn to c...      False   MC     MAVR
# 14  What online courses or certifications do you u...      False   MC     MAVR
# 15  Including any education, how many years have y...      False   MC       DL
# 16  NOT including education, how many years have y...      False   MC       DL
# 17  Which of the following describes your current ...      False   MC     SAVR
# 18  Approximately how many people are employed by ...      False   MC     SAVR
# 19  What level of influence do you, personally, ha...      False   MC     SAVR
# 20  When thinking about new technology purchases a...      False   MC     SAVR
# 21  When buying a new tool or software, how do you...      False   MC     MAVR
# 22  Where do you live? <span style="font-weight: b...       True   MC       DL
# 23  Which currency do you use day-to-day? If your ...       True   MC       DL
# 24  What is your current total <b>annual</b> compe...      False   TE       SL

# %% [markdown]
# Section 3 / Technology, Tech Culture

# %%
section3_df = schema_data.iloc[schema_data[schema_data["qname"] == "S3"].index[0]: schema_data[schema_data["qname"] == "S4"].index[0]]
section3_df
# Out:
#        qid             qname  \
# 25   QID61                S3
# 26  QID233          Language
# 27  QID262          Database
# 28  QID263          Platform
# 29  QID264          Webframe
# 30  QID265          MiscTech
# 31  QID275         ToolsTech
# 32  QID274    NEWCollabTools
# 33   QID71             OpSys
# 34  QID282  OfficeStackAsync
# 35  QID307   OfficeStackSync
# 36  QID327          AISearch
# 37  QID328             AIDev
#
#                                              question force_resp    type  \
# 25  <span style="font-size:22px; font-family: aria...      False      DB
# 26  Which <b>programming, scripting, and markup la...      False  Matrix
# 27  Which <b>database environments </b>have you do...      False  Matrix
# 28  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 29  Which <b>web frameworks and web technologies</...      False  Matrix
# 30  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 31  Which <b>developer </b><strong>tools for compi...      False  Matrix
# 32  Which <strong>development environments</strong...      False  Matrix
# 33  What is the primary <b>operating system</b> in...      False  Matrix
# 34  Which <b>collaborative work management and/or ...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  Which <b>AI-powered search tools</b> did you u...      False  Matrix
# 37  Which <b>AI-powered developer tools</b> did yo...      False  Matrix
#
#    selector
# 25       TB
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31   Likert
# 32   Likert
# 33   Likert
# 34   Likert
# 35   Likert
# 36   Likert
# 37   Likert

# %% [markdown]
# S4 / Stack Overflow Community

# %%
section4_df = schema_data.iloc[schema_data[schema_data["qname"] == "S4"].index[0]: schema_data[schema_data["qname"] == "S5"].index[0]]
section4_df
# Out:
#        qid        qname                                           question  \
# 38   QID91           S4  <span style="font-size:22px; font-family: aria...
# 39  QID266   NEWSOSites  Which of the following Stack Overflow sites ha...
# 40  QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# 41  QID101    SOAccount              Do you have a Stack Overflow account?
# 42  QID102   SOPartFreq  How frequently would you say you participate i...
# 43  QID106       SOComm  Do you consider yourself a member of the Stack...
#
#    force_resp type selector
# 38      False   DB       TB
# 39       True   MC     MAVR
# 40      False   MC     SAVR
# 41      False   MC     SAVR
# 42      False   MC     SAVR
# 43      False   MC     SAVR

# %% [markdown]
# Section 5 /  Artificial Intelligence

# %%
section5_df = schema_data.iloc[schema_data[schema_data["qname"] == "S5"].index[0]: schema_data[schema_data["qname"] == "S6"].index[0]]
section5_df
# Out:
#        qid     qname                                           question  \
# 44  QID313        S5  <span style="font-size:22px; font-family: aria...
# 45  QID325      SOAI  Artificial Intelligence (AI) tools have gained...
# 46  QID314  AISelect  Do you currently use AI tools in your developm...
# 47  QID315    AISent  How favorable is your stance on using AI tools...
# 48  QID324     AIAcc  For the AI tools you use as part of your devel...
# 49  QID316     AIBen  How much do you trust the accuracy of the outp...
# 50  QID319    AITool  Which parts of your development workflow are y...
# 51  QID320    AINext  Thinking about how your workflow and process c...
# 52  QID321    AIOpen  Please describe how you would expect your work...
#
#    force_resp    type selector
# 44      False      DB       TB
# 45      False      TE       SL
# 46       True      MC     SAVR
# 47      False      MC     SAVR
# 48      False      MC     MAVR
# 49      False      MC     SAVR
# 50      False  Matrix   Likert
# 51      False  Matrix   Likert
# 52      False      TE       SL

# %% [markdown]
# Section 6 / Professional Developer Series

# %%
section6_df = schema_data.iloc[schema_data[schema_data["qname"] == "S6"].index[0]: schema_data[schema_data["qname"] == "S7"].index[0]]
section6_df
# Out:
#        qid             qname  \
# 53  QID295                S6
# 54  QID299           TBranch
# 55  QID287            ICorPM
# 56  QID288           WorkExp
# 57  QID289         Knowledge
# 58  QID290         Frequency
# 59  QID291     TimeSearching
# 60  QID292     TimeAnswering
# 61  QID304  ProfessionalTech
# 62  QID326          Industry
# 63  QID286      SOTeamsUsage
#
#                                              question force_resp    type  \
# 53  <span style="font-size:22px; font-family: aria...      False      DB
# 54  <span style="font-size:16px;">Would you like t...       True      MC
# 55  Are you an individual contributor or people ma...      False      MC
# 56  How many years of working experience do you have?      False  Slider
# 57  Please rate your level of agreement with the f...      False  Matrix
# 58  How frequently do you experience each of the f...      False  Matrix
# 59  On an average day, how much time do you typica...      False      MC
# 60  On an average day, how much time do you typica...      False      MC
# 61                                    My company has:      False      MC
# 62      What industry is the company you work for in?      False      MC
# 63       Does your team use Stack Overflow for Teams?      False      MC
#
#    selector
# 53       TB
# 54     SAVR
# 55     SAVR
# 56  HSLIDER
# 57   Likert
# 58   Likert
# 59     SAVR
# 60     SAVR
# 61     MAVR
# 62     SAVR
# 63     SAVR

# %% [markdown]
# Section 7 / Final Questions

# %%
section7_df = schema_data.iloc[schema_data[schema_data["qname"] == "S7"].index[0]:]
section7_df
# Out:
#        qid         qname                                           question  \
# 64  QID131            S7  <span style="font-size:22px;"><strong>Final Qu...
# 65  QID132  SurveyLength  How do you feel about the length of the survey...
# 66  QID133    SurveyEase  How easy or difficult was this survey to compl...
# 67  QID289   Knowledge_1  I have interactions with people outside of my ...
# 68  QID289   Knowledge_2  Knowledge silos prevent me from getting ideas ...
# 69  QID289   Knowledge_3  I can find up-to-date information within my or...
# 70  QID289   Knowledge_4  I am able to quickly find answers to my questi...
# 71  QID289   Knowledge_5  I know which system or resource to use to find...
# 72  QID289   Knowledge_6  I often find myself answering questions that I...
# 73  QID289   Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289   Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290   Frequency_1  Needing help from people outside of your immed...
# 76  QID290   Frequency_2  Interacting with people outside of your immedi...
# 77  QID290   Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp type selector
# 64      False   DB       TB
# 65      False   MC     MAVR
# 66      False   MC     MAVR
# 67        NaN   MC     MAVR
# 68        NaN   MC     MAVR
# 69        NaN   MC     MAVR
# 70        NaN   MC     MAVR
# 71        NaN   MC     MAVR
# 72        NaN   MC     MAVR
# 73        NaN   MC     MAVR
# 74        NaN   MC     MAVR
# 75        NaN   MC     MAVR
# 76        NaN   MC     MAVR
# 77        NaN   MC     MAVR

# %%
georgia_data = df[df['Country'] == 'Georgia']


georgia_data.set_index('ResponseId', inplace=True)

print(georgia_data)
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 422         I agree           I am learning to code  18-24 years old
# 503         I agree  I am a developer by profession  35-44 years old
# 740         I agree  I am a developer by profession  35-44 years old
# 819         I agree  I am a developer by profession  35-44 years old
# 1674        I agree  I am a developer by profession  35-44 years old
# ...             ...                             ...              ...
# 86065       I agree  I am a developer by profession  25-34 years old
# 87401       I agree  I am a developer by profession  18-24 years old
# 87734       I agree  I am a developer by profession  18-24 years old
# 88410       I agree           I am learning to code  35-44 years old
# 89028       I agree  I am a developer by profession  45-54 years old
#
#                                                    Employment  \
# ResponseId
# 422                        Not employed, but looking for work
# 503                                       Employed, full-time
# 740                                       Employed, full-time
# 819                                       Employed, full-time
# 1674                                      Employed, full-time
# ...                                                       ...
# 86065                                     Employed, part-time
# 87401                                     Employed, full-time
# 87734       Employed, full-time;Independent contractor, fr...
# 88410                      Not employed, but looking for work
# 89028                                     Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 422                                          NaN
# 503                                    In-person
# 740         Hybrid (some remote, some in-person)
# 819                                       Remote
# 1674        Hybrid (some remote, some in-person)
# ...                                          ...
# 86065                                     Remote
# 87401                                     Remote
# 87734       Hybrid (some remote, some in-person)
# 88410                                        NaN
# 89028       Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 422                                                       NaN
# 503         Hobby;Professional development or self-paced l...
# 740                             Hobby;Freelance/contract work
# 819                             Hobby;Freelance/contract work
# 1674                 Hobby;Contribute to open-source projects
# ...                                                       ...
# 86065       Hobby;Professional development or self-paced l...
# 87401       Hobby;Bootstrapping a business;Professional de...
# 87734                           Hobby;Freelance/contract work
# 88410                                                     NaN
# 89028                                                   Hobby
#
#                                                       EdLevel  \
# ResponseId
# 422         Some college/university study without earning ...
# 503           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 740            Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 819              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1674             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 86065       Some college/university study without earning ...
# 87401       Secondary school (e.g. American high school, G...
# 87734       Secondary school (e.g. American high school, G...
# 88410       Some college/university study without earning ...
# 89028            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 422         Online Courses or Certification;On the job tra...
# 503               On the job training;Other (please specify):
# 740                           Online Courses or Certification
# 819         Colleague;Other online resources (e.g., videos...
# 1674        Books / Physical media;Other online resources ...
# ...                                                       ...
# 86065                  Books / Physical media;Coding Bootcamp
# 87401       Online Courses or Certification;Other online r...
# 87734       Online Courses or Certification;Other online r...
# 88410       Books / Physical media;Online Courses or Certi...
# 89028       Books / Physical media;Colleague;Friend or fam...
#
#                                               LearnCodeOnline  \
# ResponseId
# 422         Formal documentation provided by the owner of ...
# 503                                                       NaN
# 740                                                       NaN
# 819         Formal documentation provided by the owner of ...
# 1674        Formal documentation provided by the owner of ...
# ...                                                       ...
# 86065                                                     NaN
# 87401       Formal documentation provided by the owner of ...
# 87734       Formal documentation provided by the owner of ...
# 88410       Formal documentation provided by the owner of ...
# 89028       Formal documentation provided by the owner of ...
#
#                           LearnCodeCoursesCert  ...       Frequency_1  \
# ResponseId                                      ...
# 422                                   Coursera  ...               NaN
# 503                                        NaN  ...               NaN
# 740         Udemy;Pluralsight;Coursera;Udacity  ...  1-2 times a week
# 819                                        NaN  ...  1-2 times a week
# 1674                                       NaN  ...  1-2 times a week
# ...                                        ...  ...               ...
# 86065                                      NaN  ...               NaN
# 87401                                    Udemy  ...  1-2 times a week
# 87734                        Udemy;Pluralsight  ...  1-2 times a week
# 88410                               Codecademy  ...               NaN
# 89028                Codecademy;Udemy;Coursera  ...  1-2 times a week
#
#                  Frequency_2        Frequency_3               TimeSearching  \
# ResponseId
# 422                      NaN                NaN                         NaN
# 503                      NaN   1-2 times a week         15-30 minutes a day
# 740         1-2 times a week   3-5 times a week         15-30 minutes a day
# 819         1-2 times a week              Never  Less than 15 minutes a day
# 1674        1-2 times a week   3-5 times a week         30-60 minutes a day
# ...                      ...                ...                         ...
# 86065                    NaN                NaN                         NaN
# 87401       3-5 times a week   3-5 times a week  Less than 15 minutes a day
# 87734       1-2 times a week  6-10 times a week         15-30 minutes a day
# 88410                    NaN                NaN                         NaN
# 89028       1-2 times a week   3-5 times a week         30-60 minutes a day
#
#                          TimeAnswering  \
# ResponseId
# 422                                NaN
# 503         Less than 15 minutes a day
# 740         Less than 15 minutes a day
# 819                15-30 minutes a day
# 1674               30-60 minutes a day
# ...                                ...
# 86065                              NaN
# 87401       Less than 15 minutes a day
# 87734              15-30 minutes a day
# 88410                              NaN
# 89028              15-30 minutes a day
#
#                                              ProfessionalTech  \
# ResponseId
# 422                                                       NaN
# 503                             DevOps function;Microservices
# 740         DevOps function;Continuous integration (CI) an...
# 819         Microservices;Developer portal or other centra...
# 1674        DevOps function;Microservices;Automated testin...
# ...                                                       ...
# 86065                                                     NaN
# 87401                                           None of these
# 87734       DevOps function;Microservices;Automated testin...
# 88410                                                     NaN
# 89028       DevOps function;Microservices;Automated testin...
#
#                                                      Industry  \
# ResponseId
# 422                                                       NaN
# 503                                                       NaN
# 740         Information Services, IT, Software Development...
# 819                                                     Other
# 1674                                       Financial Services
# ...                                                       ...
# 86065                                                     NaN
# 87401                                    Advertising Services
# 87734       Information Services, IT, Software Development...
# 88410                                                     NaN
# 89028                                      Financial Services
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 422         Appropriate in length  Neither easy nor difficult
# 503         Appropriate in length  Neither easy nor difficult
# 740         Appropriate in length  Neither easy nor difficult
# 819         Appropriate in length                        Easy
# 1674        Appropriate in length                        Easy
# ...                           ...                         ...
# 86065                         NaN                         NaN
# 87401       Appropriate in length  Neither easy nor difficult
# 87734       Appropriate in length                        Easy
# 88410                    Too long  Neither easy nor difficult
# 89028       Appropriate in length  Neither easy nor difficult
#
#             ConvertedCompYearly
# ResponseId
# 422                         NaN
# 503                  19,152.000
# 740                         NaN
# 819                  76,607.000
# 1674                 48,645.000
# ...                         ...
# 86065                       NaN
# 87401                 4,596.000
# 87734                39,989.000
# 88410                       NaN
# 89028                       NaN
#
# [166 rows x 83 columns]

# %% [markdown]
# I'm going to drop some of the columns which I don't use in the analysis. CHASASWOREBELIA EGI
#
#
# ---

# %%
mandatory_columns = ["MainBranch", "Country", "Currency", "EdLevel"]
georgia_data.dropna(subset=mandatory_columns, inplace=True)

dropped_labels = [ 'Q120' ,  'OrgSize','TimeSearching','TimeAnswering','TBranch', 'ICorPM','PurchaseInfluence', 'BuyNewTool']
georgia_data.drop(columns=dropped_labels, inplace=True)

print(georgia_data.columns)
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'CodingActivities',
#        'EdLevel', 'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert',
#        'YearsCode', 'YearsCodePro', 'DevType', 'TechList', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
#        'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
#        'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm',
#        'SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
#        'AIToolInterested in Using', 'AIToolCurrently Using',
#        'AIToolNot interested in Using', 'AINextVery different',
#        'AINextNeither different nor similar', 'AINextSomewhat similar',
#        'AINextVery similar', 'AINextSomewhat different', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
#        'Frequency_1', 'Frequency_2', 'Frequency_3', 'ProfessionalTech',
#        'Industry', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')
# <ipython-input-95-d949a0bd1513>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   georgia_data.dropna(subset=mandatory_columns, inplace=True)
# <ipython-input-95-d949a0bd1513>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   georgia_data.drop(columns=dropped_labels, inplace=True)

# %%
print(georgia_data.columns)
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'CodingActivities',
#        'EdLevel', 'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert',
#        'YearsCode', 'YearsCodePro', 'DevType', 'TechList', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
#        'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
#        'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm',
#        'SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
#        'AIToolInterested in Using', 'AIToolCurrently Using',
#        'AIToolNot interested in Using', 'AINextVery different',
#        'AINextNeither different nor similar', 'AINextSomewhat similar',
#        'AINextVery similar', 'AINextSomewhat different', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
#        'Frequency_1', 'Frequency_2', 'Frequency_3', 'ProfessionalTech',
#        'Industry', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %% [markdown]
# We must convert the multiple answered columns into a binary column, so we can understand and analyse these columns separately.

# %%
multiple_answer_columns = ['DevType',
       'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith','DatabaseWantToWorkWith', 'PlatformHaveWorkedWith','PlatformWantToWorkWith', 'WebframeHaveWorkedWith','WebframeWantToWorkWith',
       'MiscTechHaveWorkedWith','MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith','ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith','NEWCollabToolsWantToWorkWith', 'OpSysProfessional use', 'OpSysPersonal use',

       'OfficeStackAsyncHaveWorkedWith','OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith','OfficeStackSyncWantToWorkWith','AISearchHaveWorkedWith',
       'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
       'ProfessionalTech']
for i in multiple_answer_columns:
    unique_values = df[i].unique()
    unique_values = [x for x in unique_values if type(x) != float]
    unique_list_values = []
    for j in unique_values:
        something = j.split(";")
        for k in something:
            unique_list_values.append(k)
    unique_list_array = np.array(unique_list_values)
    unique_list_array = np.unique(unique_list_array)
    for element in unique_list_array:
         df["{}_{}".format(i, element)] = np.nan

# %%
for i in multiple_answer_columns:
    semicolon_values =  df[ df[i].str.contains(";", na=False)][i].values
    semicolon_indexes = df[ df[i].str.contains(";", na=False)][i].index
    counter = 0
    for j in semicolon_values:
        element = j.split(";")
        for k in element:
             df.loc[semicolon_indexes[counter], "{}_{}".format(i, k)] = 1
        counter += 1
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# CompTotal groupby DevType

# %%
grouped_data = georgia_data.groupby('DevType')


total_comp_by_devtype = grouped_data['CompTotal'].sum()



result_df = total_comp_by_devtype.reset_index()

result_df = result_df.merge(georgia_data[['DevType', 'Currency']], on='DevType', how='left')

print(result_df)
# Out:
#                                            DevType   CompTotal  \
# 0                                       Blockchain       0.000
# 1                    Cloud infrastructure engineer 200,000.000
# 2                    Cloud infrastructure engineer 200,000.000
# 3    Data scientist or machine learning specialist 282,250.000
# 4    Data scientist or machine learning specialist 282,250.000
# ..                                             ...         ...
# 130                    Research & Development role       0.000
# 131           Senior Executive (C-Suite, VP, etc.) 140,000.000
# 132           Senior Executive (C-Suite, VP, etc.) 140,000.000
# 133                           System administrator 120,000.000
# 134                           System administrator 120,000.000
#
#                       Currency
# 0           GEL\tGeorgian lari
# 1    USD\tUnited States dollar
# 2    USD\tUnited States dollar
# 3           GEL\tGeorgian lari
# 4    USD\tUnited States dollar
# ..                         ...
# 130  USD\tUnited States dollar
# 131         GEL\tGeorgian lari
# 132         GEL\tGeorgian lari
# 133         GEL\tGeorgian lari
# 134         GEL\tGeorgian lari
#
# [135 rows x 3 columns]

# %%
georgia_data['YearsCodePro'] = pd.to_numeric(georgia_data['YearsCodePro'], errors='coerce')


mean_yearscodepro = georgia_data['YearsCodePro'].mean()


mean_workexp = georgia_data['WorkExp'].mean()

print(f"Mean YearsCodePro: {mean_yearscodepro}")
print(f"Mean WorkExp: {mean_workexp}")
# Out:
# Mean YearsCodePro: 9.174242424242424
# Mean WorkExp: 10.097826086956522
# <ipython-input-100-7236f0d7bd34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   georgia_data['YearsCodePro'] = pd.to_numeric(georgia_data['YearsCodePro'], errors='coerce')

# %%
yearscodepro_F = 9
workexp_F = 9


filterrr = (georgia_data['YearsCodePro'] >= yearscodepro_F) & (georgia_data['WorkExp'] == workexp_F)


filtered_df = georgia_data.loc[filterrr, ['YearsCodePro', 'WorkExp']]

print(filtered_df)
# Out:
#             YearsCodePro  WorkExp
# ResponseId
# 22268              9.000    9.000
# 27136              9.000    9.000
# 29513             12.000    9.000
# 47789             11.000    9.000
# 62814              9.000    9.000

# %% [markdown]
# Sorting age with comptotal

# %%
sorted_data = georgia_data.sort_values(by=['Age', 'CompTotal'])


col = sorted_data.loc[:, ['Age', 'CompTotal', 'Currency']]

print(col)
# Out:
#                            Age   CompTotal                   Currency
# ResponseId
# 49285          18-24 years old   7,250.000         GEL\tGeorgian lari
# 50531          18-24 years old   9,000.000         GEL\tGeorgian lari
# 55820          18-24 years old  12,000.000         GEL\tGeorgian lari
# 87401          18-24 years old  12,000.000         GEL\tGeorgian lari
# 72056          18-24 years old  14,000.000  USD\tUnited States dollar
# ...                        ...         ...                        ...
# 19683          45-54 years old 120,000.000         GEL\tGeorgian lari
# 20512          45-54 years old 120,000.000         GEL\tGeorgian lari
# 89028          45-54 years old         NaN  USD\tUnited States dollar
# 63278        Prefer not to say         NaN         GEL\tGeorgian lari
# 38831       Under 18 years old         NaN         GEL\tGeorgian lari
#
# [136 rows x 3 columns]

# %%
all_languages = []
for row in georgia_data['LanguageHaveWorkedWith']:
    languages = row.split(';')
    all_languages.extend(languages)


language_counts = pd.Series(all_languages).value_counts()


print(language_counts)
# Out:
# JavaScript                 81
# HTML/CSS                   62
# TypeScript                 54
# SQL                        49
# Python                     48
# Bash/Shell (all shells)    32
# C#                         31
# PHP                        25
# Java                       24
# Go                         21
# C++                        18
# Rust                       17
# C                          15
# Ruby                       13
# Kotlin                     13
# PowerShell                 12
# Swift                      10
# Elixir                      7
# Lua                         7
# Dart                        7
# Scala                       5
# Groovy                      5
# Lisp                        4
# GDScript                    4
# Solidity                    4
# Objective-C                 3
# Ada                         3
# Delphi                      3
# Erlang                      3
# R                           3
# MATLAB                      3
# Julia                       3
# Nim                         2
# Flow                        2
# Crystal                     2
# Zig                         2
# Assembly                    2
# Perl                        2
# Clojure                     2
# Haskell                     2
# Apex                        1
# APL                         1
# Cobol                       1
# F#                          1
# Fortran                     1
# OCaml                       1
# Prolog                      1
# Raku                        1
# SAS                         1
# VBA                         1
# Visual Basic (.Net)         1
# dtype: int64

# %%
all_wanted_languages = []

for row in georgia_data['LanguageWantToWorkWith']:
    if isinstance(row, str):
        wanted_languages = row.split(';')
        all_wanted_languages.extend(wanted_languages)


wanted_language_counts = pd.Series(all_wanted_languages).value_counts()

print(wanted_language_counts)
# Out:
# TypeScript                 50
# Rust                       49
# JavaScript                 42
# Python                     39
# HTML/CSS                   33
# SQL                        31
# Go                         25
# C#                         23
# Kotlin                     18
# Bash/Shell (all shells)    18
# C++                        17
# Dart                       12
# Swift                      11
# PHP                         9
# Zig                         9
# Java                        8
# Ruby                        8
# Haskell                     7
# Elixir                      6
# GDScript                    5
# C                           5
# Julia                       4
# F#                          4
# Solidity                    4
# Lisp                        4
# Scala                       3
# R                           3
# Erlang                      3
# Assembly                    3
# Lua                         3
# PowerShell                  3
# OCaml                       2
# Ada                         2
# Crystal                     2
# Clojure                     2
# Nim                         1
# Raku                        1
# Perl                        1
# Delphi                      1
# Groovy                      1
# dtype: int64

# %%
all_WORKED_DB = []

for row in georgia_data['DatabaseHaveWorkedWith']:
    if isinstance(row, str):
        worked_DB = row.split(';')
        all_WORKED_DB.extend(worked_DB)


worked_DB = pd.Series(all_WORKED_DB).value_counts()

print(worked_DB)
# Out:
# PostgreSQL                    74
# Redis                         45
# MongoDB                       42
# MySQL                         37
# SQLite                        33
# Microsoft SQL Server          26
# MariaDB                       16
# Elasticsearch                 16
# Dynamodb                      13
# Clickhouse                     9
# Oracle                         9
# Cloud Firestore                7
# Cassandra                      5
# BigQuery                       4
# Snowflake                      4
# Supabase                       3
# Firebase Realtime Database     3
# Cosmos DB                      3
# Neo4J                          3
# Cockroachdb                    2
# H2                             2
# Datomic                        2
# Solr                           2
# RavenDB                        2
# IBM DB2                        2
# InfluxDB                       1
# Couchbase                      1
# Firebird                       1
# DuckDB                         1
# Couch DB                       1
# TiDB                           1
# dtype: int64

# %%
all_WNTD_DB = []

for row in georgia_data['DatabaseWantToWorkWith']:
    if isinstance(row, str):
        wntd_DB = row.split(';')  #
        all_WNTD_DB.extend(worked_DB)


wntd_DB = pd.Series(all_WNTD_DB).value_counts()

print(worked_DB)
# Out:
# PostgreSQL                    74
# Redis                         45
# MongoDB                       42
# MySQL                         37
# SQLite                        33
# Microsoft SQL Server          26
# MariaDB                       16
# Elasticsearch                 16
# Dynamodb                      13
# Clickhouse                     9
# Oracle                         9
# Cloud Firestore                7
# Cassandra                      5
# BigQuery                       4
# Snowflake                      4
# Supabase                       3
# Firebase Realtime Database     3
# Cosmos DB                      3
# Neo4J                          3
# Cockroachdb                    2
# H2                             2
# Datomic                        2
# Solr                           2
# RavenDB                        2
# IBM DB2                        2
# InfluxDB                       1
# Couchbase                      1
# Firebird                       1
# DuckDB                         1
# Couch DB                       1
# TiDB                           1
# dtype: int64

# %% [markdown]
# Percent of why they currentyl useing AI for Each DEVtype

# %%
filtered_data = georgia_data.dropna(subset=['DevType', 'AIToolCurrently Using'])


grouped_data = filtered_data.groupby('DevType')


percentage_of_ai_users = (grouped_data['AIToolCurrently Using'].value_counts(normalize=True) * 100).reset_index(name='Percentage')

print(percentage_of_ai_users)
# Out:
#                                           DevType  \
# 0                                      Blockchain
# 1                   Cloud infrastructure engineer
# 2                   Cloud infrastructure engineer
# 3   Data scientist or machine learning specialist
# 4   Data scientist or machine learning specialist
# 5                               DevOps specialist
# 6                               DevOps specialist
# 7                           Developer, QA or test
# 8                             Developer, back-end
# 9                             Developer, back-end
# 10                            Developer, back-end
# 11                            Developer, back-end
# 12                            Developer, back-end
# 13                            Developer, back-end
# 14                            Developer, back-end
# 15                            Developer, back-end
# 16                            Developer, back-end
# 17                            Developer, back-end
# 18                            Developer, back-end
# 19                            Developer, back-end
# 20                            Developer, back-end
# 21  Developer, desktop or enterprise applications
# 22  Developer, desktop or enterprise applications
# 23                           Developer, front-end
# 24                           Developer, front-end
# 25                           Developer, front-end
# 26                          Developer, full-stack
# 27                          Developer, full-stack
# 28                          Developer, full-stack
# 29                          Developer, full-stack
# 30                          Developer, full-stack
# 31                          Developer, full-stack
# 32                          Developer, full-stack
# 33                          Developer, full-stack
# 34                          Developer, full-stack
# 35                          Developer, full-stack
# 36                          Developer, full-stack
# 37                          Developer, full-stack
# 38                          Developer, full-stack
# 39                    Developer, game or graphics
# 40                    Developer, game or graphics
# 41                    Developer, game or graphics
# 42                    Developer, game or graphics
# 43                              Developer, mobile
# 44                              Developer, mobile
# 45                              Developer, mobile
# 46                              Developer, mobile
# 47                        Other (please specify):
# 48                    Research & Development role
# 49           Senior Executive (C-Suite, VP, etc.)
# 50                           System administrator
#
#                                 AIToolCurrently Using  Percentage
# 0                                        Writing code     100.000
# 1                           Learning about a codebase      50.000
# 2   Learning about a codebase;Writing code;Documen...      50.000
# 3                                        Writing code      66.667
# 4   Learning about a codebase;Project planning;Wri...      33.333
# 5   Learning about a codebase;Writing code;Debuggi...      50.000
# 6                                        Writing code      50.000
# 7   Debugging and getting help;Committing and revi...     100.000
# 8                                        Writing code      28.571
# 9                           Learning about a codebase       9.524
# 10             Learning about a codebase;Writing code       9.524
# 11  Writing code;Debugging and getting help;Commit...       9.524
# 12                         Debugging and getting help       4.762
# 13                                   Documenting code       4.762
# 14  Learning about a codebase;Debugging and gettin...       4.762
# 15  Learning about a codebase;Writing code;Testing...       4.762
# 16                      Writing code;Documenting code       4.762
# 17  Writing code;Documenting code;Debugging and ge...       4.762
# 18  Writing code;Documenting code;Debugging and ge...       4.762
# 19         Writing code;Documenting code;Testing code       4.762
# 20                          Writing code;Testing code       4.762
# 21                                       Writing code      66.667
# 22                         Debugging and getting help      33.333
# 23         Learning about a codebase;Project planning      33.333
# 24  Learning about a codebase;Project planning;Wri...      33.333
# 25            Writing code;Debugging and getting help      33.333
# 26                                       Writing code      27.778
# 27                      Writing code;Documenting code      11.111
# 28                         Debugging and getting help       5.556
# 29         Learning about a codebase;Documenting code       5.556
# 30  Learning about a codebase;Project planning;Wri...       5.556
# 31  Learning about a codebase;Project planning;Wri...       5.556
# 32             Learning about a codebase;Writing code       5.556
# 33  Learning about a codebase;Writing code;Documen...       5.556
# 34            Writing code;Debugging and getting help       5.556
# 35  Writing code;Debugging and getting help;Testin...       5.556
# 36  Writing code;Documenting code;Committing and r...       5.556
# 37  Writing code;Documenting code;Debugging and ge...       5.556
# 38                          Writing code;Testing code       5.556
# 39  Learning about a codebase;Writing code;Documen...      25.000
# 40                            Other (please describe)      25.000
# 41  Writing code;Debugging and getting help;Commit...      25.000
# 42                      Writing code;Documenting code      25.000
# 43         Project planning;Writing code;Testing code      25.000
# 44                      Writing code;Documenting code      25.000
# 45  Writing code;Documenting code;Debugging and ge...      25.000
# 46  Writing code;Documenting code;Testing code;Com...      25.000
# 47  Learning about a codebase;Writing code;Debuggi...     100.000
# 48  Debugging and getting help;Other (please descr...     100.000
# 49                                   Project planning     100.000
# 50                                       Writing code     100.000

# %%
grouped_data = georgia_data.groupby('DevType')


statistics_by_age = grouped_data['ConvertedCompYearly'].agg(['mean', 'std', 'median'])


print(statistics_by_age)
# Out:
#                                                      mean        std  \
# DevType
# Blockchain                                            NaN        NaN
# Cloud infrastructure engineer                 100,000.000 56,568.542
# Data scientist or machine learning specialist  71,980.500 24,983.225
# DevOps specialist                              39,500.500 23,360.687
# Developer, QA or test                          38,303.000        NaN
# Developer, back-end                            51,218.667 33,565.805
# Developer, desktop or enterprise applications  71,533.333 28,223.530
# Developer, embedded applications or devices    91,026.000        NaN
# Developer, front-end                           50,369.714 20,192.099
# Developer, full-stack                          38,959.714 32,922.881
# Developer, game or graphics                    54,696.500 14,769.147
# Developer, mobile                              65,327.500 21,055.350
# Engineer, data                                 76,607.000        NaN
# Engineering manager                            49,503.000        NaN
# Hardware Engineer                              14,090.000        NaN
# Other (please specify):                        71,700.333 71,613.143
# Research & Development role                           NaN        NaN
# Senior Executive (C-Suite, VP, etc.)           53,625.000        NaN
# System administrator                           45,964.000        NaN
#
#                                                    median
# DevType
# Blockchain                                            NaN
# Cloud infrastructure engineer                 100,000.000
# Data scientist or machine learning specialist  70,336.000
# DevOps specialist                              39,500.500
# Developer, QA or test                          38,303.000
# Developer, back-end                            49,219.500
# Developer, desktop or enterprise applications  66,000.000
# Developer, embedded applications or devices    91,026.000
# Developer, front-end                           47,000.000
# Developer, full-stack                          32,100.000
# Developer, game or graphics                    57,127.000
# Developer, mobile                              68,303.500
# Engineer, data                                 76,607.000
# Engineering manager                            49,503.000
# Hardware Engineer                              14,090.000
# Other (please specify):                        42,290.000
# Research & Development role                           NaN
# Senior Executive (C-Suite, VP, etc.)           53,625.000
# System administrator                           45,964.000

# %%
age_groups = np.array(georgia_data["Age"].value_counts().index)
for i in age_groups:
    plt.figure(figsize=(15,10))
    circle = plt.Circle((0,0),0.5,color = "white")
    plt.pie(np.array(georgia_data[georgia_data["Age"] == i]["DevType"].value_counts(normalize=True).values[:8]), labels = np.array(georgia_data[georgia_data["Age"] == i]["DevType"].value_counts(normalize=True).index[:8]), autopct='%.2f')
    p = plt.gcf()
    p.gca().add_artist(circle)
    plt.title("Developer titles of {} people".format(i))
    plt.show()

# %% [markdown]
# Most popular Educational Level

# %%
category_counts = df['EdLevel'].value_counts()
plt.figure(figsize=(8, 8))


plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)

plt.title('Educational Level')

plt.show()
